# %% [markdown]
# # Validation by Policy
#
# Policy assertions can be expressed according to the [Rego Policy language](https://www.openpolicyagent.org/docs/policy-language)  directly inside in the original CWL Workflow as a Hint

# %%
module = '''
package workflow

# --- BBOX sanity checks ---

deny_bbox[msg] {
  b := input.aoi.bbox
  not valid_bbox(b)
  msg := sprintf("invalid aoi.bbox: %v", [b])
}

valid_bbox(b) {
  count(b) == 4
  b[0] >= -180
  b[2] <= 180
  b[1] >= -90
  b[3] <= 90
  b[0] < b[2]
  b[1] < b[3]
}

# --- Bands sanity checks ("green" must be first; second is "nir" or "nir08") ---

deny_bands[msg] {
  b := input.bands
  not valid_bands(b)
  msg := sprintf("invalid bands: %v", [b])
}

valid_bands(b) {
  count(b) == 2
  b[0] == "green"
  allowed_nir(b[1])
}

# helper predicate for the allowed second band (disjunction via multiple rules)
allowed_nir(x) { x == "nir" }
allowed_nir(x) { x == "nir08" }
'''

# List the deny queries you want to collect messages from
deny_queries = [
    "data.workflow.deny_bbox[_]",
    "data.workflow.deny_bands[_]",
]

# %% [markdown]
# ## 1. Parse the Rego module

# %%
from assertions_mate import RegoPolicyHint

validator = RegoPolicyHint(module=module, queries=deny_queries).validator()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 from assertions_mate.hints_models import RegoPolicyHint
#       2 from assertions_mate.rego_validator import RegoValidator
# ----> 4 validator = RegoValidator(RegoPolicyHint(module=module, queries=deny_queries))
#
# File ~/Documents/workspace/assertions-mate/src/assertions_mate/rego_validator.py:29, in RegoValidator.__init__(self, hint)
#      25 def __init__(
#      26     self,
#      27     hint: RegoPolicyHint
#      28 ):
# ---> 29     self.rego = Interpreter(True)
#      30     print(hint.module)
#      31     self.rego.add_module("workflow", hint.module)
#
# File ~/Documents/workspace/assertions-mate/.venv/lib/python3.13/site-packages/regopy/interpreter.py:97, in Interpreter.__init__(self, v1_compatible)
#      95 def __init__(self, v1_compatible=False):
#      96     """Initializer."""
# ---> 97     self._impl = rego_new_v1() if v1_compatible else rego_new()
#
# TypeError: this function takes at least 1 argument (0 given)

# %% [markdown]
# ## 2. Define your inputs set

# %%
inputs = {
    "aoi": {
        "bbox": [
            -1181.985,
            38.432,
            -118.183,
            38.938
        ],
        "crs": "CRS84"
    },
    "filesB": "EPSG:4326",
    "bands": [ "green", "nir089" ],
    "item": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC08_L2SP_042033_20231007_02_T1"
}

# %% [markdown]
# ## 3. Validate the inputs and report the errors

# %%
error = validator.validate_inputs(inputs)

if error:
    print(error.model_dump_json(indent=2, exclude_none=True))
else:
    # No violations — choose what to output. A simple success marker is fine:
    print("Go ahead on submitting the request to the next level validation")
